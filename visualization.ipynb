# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
disorders = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Mental health Depression disorder Data.xlsx")

# %%
disorders
# Out:
#            Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0     Afghanistan  AFG  1990           0.160560              0.697779
# 1     Afghanistan  AFG  1991           0.160312              0.697961
# 2     Afghanistan  AFG  1992           0.160135              0.698107
# 3     Afghanistan  AFG  1993           0.160037              0.698257
# 4     Afghanistan  AFG  1994           0.160022              0.698469
# ...           ...  ...   ...                ...                   ...
# 6463     Zimbabwe  ZWE  2013           0.155670              0.607993
# 6464     Zimbabwe  ZWE  2014           0.155993              0.608610
# 6465     Zimbabwe  ZWE  2015           0.156465              0.609363
# 6466     Zimbabwe  ZWE  2016           0.157111              0.610234
# 6467     Zimbabwe  ZWE  2017           0.157963              0.611242
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0                 0.101855               4.828830                1.677082
# 1                 0.099313               4.829740                1.684746
# 2                 0.096692               4.831108                1.694334
# 3                 0.094336               4.830864                1.705320
# 4                 0.092439               4.829423                1.716069
# ...                    ...                    ...                     ...
# 6463              0.117248               3.090168                0.766280
# 6464              0.118073               3.093964                0.768914
# 6465              0.119470               3.098687                0.771802
# 6466              0.121456               3.104294                0.772275
# 6467              0.124443               3.110926                0.772648
#
#       Depression (%)  Alcohol use disorders (%)
# 0           4.071831                   0.672404
# 1           4.079531                   0.671768
# 2           4.088358                   0.670644
# 3           4.096190                   0.669738
# 4           4.099582                   0.669260
# ...              ...                        ...
# 6463        3.128192                   1.515641
# 6464        3.140290                   1.515470
# 6465        3.155710                   1.514751
# 6466        3.174134                   1.513269
# 6467        3.192789                   1.510943
#
# [6468 rows x 10 columns]

# %%
disorders.sample()
# Out:
#                           Entity Code  Year  Schizophrenia (%)  \
# 1763  Eastern Sub-Saharan Africa  NaN  2017           0.163459
#
#       Bipolar disorder (%)  Eating disorders (%)  Anxiety disorders (%)  \
# 1763              0.623965              0.116033               3.645706
#
#       Drug use disorders (%)  Depression (%)  Alcohol use disorders (%)
# 1763                0.510433        3.824305                   1.612554

# %%
disorders.sample(3)
# Out:
#        Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 1773  Ecuador  ECU  1999           0.196080              0.867131
# 1347    Congo  COG  1993           0.166106              0.609411
# 2928   Jordan  JOR  2006           0.191883              0.809897
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 1773              0.305501               4.233368                0.615478
# 1347              0.145530               3.262831                0.625635
# 2928              0.171548               4.924365                1.401364
#
#       Depression (%)  Alcohol use disorders (%)
# 1773        2.910579                   1.880847
# 1347        4.205195                   1.590477
# 2928        3.673622                   0.636149

# %%
disorders.shape
# Out:
# (6468, 10)

# %%
disorders.size
# Out:
# 64680

# %%
disorders.ndim
# Out:
# 2

# %%
disorders.info
# Out:
# <bound method DataFrame.info of            Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0     Afghanistan  AFG  1990           0.160560              0.697779
# 1     Afghanistan  AFG  1991           0.160312              0.697961
# 2     Afghanistan  AFG  1992           0.160135              0.698107
# 3     Afghanistan  AFG  1993           0.160037              0.698257
# 4     Afghanistan  AFG  1994           0.160022              0.698469
# ...           ...  ...   ...                ...                   ...
# 6463     Zimbabwe  ZWE  2013           0.155670              0.607993
# 6464     Zimbabwe  ZWE  2014           0.155993              0.608610
# 6465     Zimbabwe  ZWE  2015           0.156465              0.609363
# 6466     Zimbabwe  ZWE  2016           0.157111              0.610234
# 6467     Zimbabwe  ZWE  2017           0.157963              0.611242
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0                 0.101855               4.828830                1.677082
# 1                 0.099313               4.829740                1.684746
# 2                 0.096692               4.831108                1.694334
# 3                 0.094336               4.830864                1.705320
# 4                 0.092439               4.829423                1.716069
# ...                    ...                    ...                     ...
# 6463              0.117248               3.090168                0.766280
# 6464              0.118073               3.093964                0.768914
# 6465              0.119470               3.098687                0.771802
# 6466              0.121456               3.104294                0.772275
# 6467              0.124443               3.110926                0.772648
#
#       Depression (%)  Alcohol use disorders (%)
# 0           4.071831                   0.672404
# 1           4.079531                   0.671768
# 2           4.088358                   0.670644
# 3           4.096190                   0.669738
# 4           4.099582                   0.669260
# ...              ...                        ...
# 6463        3.128192                   1.515641
# 6464        3.140290                   1.515470
# 6465        3.155710                   1.514751
# 6466        3.174134                   1.513269
# 6467        3.192789                   1.510943
#
# [6468 rows x 10 columns]>

# %%
disorders.index
# Out:
# RangeIndex(start=0, stop=6468, step=1)

# %%
disorders.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Schizophrenia (%)', 'Bipolar disorder (%)',
#        'Eating disorders (%)', 'Anxiety disorders (%)',
#        'Drug use disorders (%)', 'Depression (%)',
#        'Alcohol use disorders (%)'],
#       dtype='object')

# %%
disorders.dtypes
# Out:
# Entity                        object
# Code                          object
# Year                           int64
# Schizophrenia (%)            float64
# Bipolar disorder (%)         float64
# Eating disorders (%)         float64
# Anxiety disorders (%)        float64
# Drug use disorders (%)       float64
# Depression (%)               float64
# Alcohol use disorders (%)    float64
# dtype: object

# %%
disorders.count()
# Out:
# Entity                       6468
# Code                         5488
# Year                         6468
# Schizophrenia (%)            6468
# Bipolar disorder (%)         6468
# Eating disorders (%)         6468
# Anxiety disorders (%)        6468
# Drug use disorders (%)       6468
# Depression (%)               6468
# Alcohol use disorders (%)    6468
# dtype: int64

# %%
disorders.nunique()
# Out:
# Entity                        231
# Code                          196
# Year                           28
# Schizophrenia (%)            6468
# Bipolar disorder (%)         6468
# Eating disorders (%)         6468
# Anxiety disorders (%)        6468
# Drug use disorders (%)       6468
# Depression (%)               6468
# Alcohol use disorders (%)    6468
# dtype: int64

# %%
disorders = disorders.rename(columns={"Schizophrenia (%)":"Schizophrenia", "Bipolar disorder (%)":"BipolarDisorder", "Eating disorders (%)":"EatingDisorders", "Anxiety disorders (%)":"AnxietyDisorders", "Drug use disorders (%)":"DrugUseDisorders", "Depression (%)":"Depression", "Alcohol use disorders (%)":"AlcoholUseDisorders"})
disorders
# Out:
#            Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 0     Afghanistan  AFG  1990       0.160560         0.697779         0.101855
# 1     Afghanistan  AFG  1991       0.160312         0.697961         0.099313
# 2     Afghanistan  AFG  1992       0.160135         0.698107         0.096692
# 3     Afghanistan  AFG  1993       0.160037         0.698257         0.094336
# 4     Afghanistan  AFG  1994       0.160022         0.698469         0.092439
# ...           ...  ...   ...            ...              ...              ...
# 6463     Zimbabwe  ZWE  2013       0.155670         0.607993         0.117248
# 6464     Zimbabwe  ZWE  2014       0.155993         0.608610         0.118073
# 6465     Zimbabwe  ZWE  2015       0.156465         0.609363         0.119470
# 6466     Zimbabwe  ZWE  2016       0.157111         0.610234         0.121456
# 6467     Zimbabwe  ZWE  2017       0.157963         0.611242         0.124443
#
#       AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 0             4.828830          1.677082    4.071831             0.672404
# 1             4.829740          1.684746    4.079531             0.671768
# 2             4.831108          1.694334    4.088358             0.670644
# 3             4.830864          1.705320    4.096190             0.669738
# 4             4.829423          1.716069    4.099582             0.669260
# ...                ...               ...         ...                  ...
# 6463          3.090168          0.766280    3.128192             1.515641
# 6464          3.093964          0.768914    3.140290             1.515470
# 6465          3.098687          0.771802    3.155710             1.514751
# 6466          3.104294          0.772275    3.174134             1.513269
# 6467          3.110926          0.772648    3.192789             1.510943
#
# [6468 rows x 10 columns]

# %%
disorders.Depression.value_counts()
# Out:
# 4.071831    1
# 3.175589    1
# 3.414441    1
# 3.414850    1
# 3.414738    1
#            ..
# 2.791195    1
# 2.789678    1
# 2.787449    1
# 2.786203    1
# 3.192789    1
# Name: Depression, Length: 6468, dtype: int64

# %%
disorders.memory_usage()
# Out:
# Index                    128
# Entity                 51744
# Code                   51744
# Year                   51744
# Schizophrenia          51744
# BipolarDisorder        51744
# EatingDisorders        51744
# AnxietyDisorders       51744
# DrugUseDisorders       51744
# Depression             51744
# AlcoholUseDisorders    51744
# dtype: int64

# %%
disorders.memory_usage(deep=True)
# Out:
# Index                     128
# Entity                 432768
# Code                   360780
# Year                    51744
# Schizophrenia           51744
# BipolarDisorder         51744
# EatingDisorders         51744
# AnxietyDisorders        51744
# DrugUseDisorders        51744
# Depression              51744
# AlcoholUseDisorders     51744
# dtype: int64

# %%
disorders.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6463    False
# 6464    False
# 6465    False
# 6466    False
# 6467    False
# Length: 6468, dtype: bool

# %%
disorders.describe()
# Out:
#               Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# count  6468.000000    6468.000000      6468.000000      6468.000000
# mean   2003.500000       0.211644         0.719145         0.239998
# std       8.078372       0.044253         0.171589         0.158141
# min    1990.000000       0.146902         0.314535         0.073908
# 25%    1996.750000       0.181530         0.615532         0.122387
# 50%    2003.500000       0.199563         0.693134         0.182525
# 75%    2010.250000       0.236365         0.835063         0.292666
# max    2017.000000       0.375110         1.206597         0.943991
#
#        AnxietyDisorders  DrugUseDisorders   Depression  AlcoholUseDisorders
# count       6468.000000       6468.000000  6468.000000          6468.000000
# mean           3.989921          0.862278     3.497654             1.585821
# std            1.167526          0.460679     0.655859             0.860283
# min            2.023393          0.383650     2.139903             0.446940
# 25%            3.188824          0.535064     3.005529             0.993685
# 50%            3.554373          0.726430     3.499606             1.479937
# 75%            4.682163          0.940157     3.912381             1.867834
# max            8.967330          3.452476     6.602754             5.474668

# %%
disorders.Depression.mean()
# Out:
# 3.497653585653159

# %%
disorders.min()
# Out:
# <ipython-input-1590-d3e448783b74>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   disorders.min()
# Entity                 Afghanistan
# Year                          1990
# Schizophrenia             0.146902
# BipolarDisorder           0.314535
# EatingDisorders           0.073908
# AnxietyDisorders          2.023393
# DrugUseDisorders           0.38365
# Depression                2.139903
# AlcoholUseDisorders        0.44694
# dtype: object

# %%
disorders.max()
# Out:
# <ipython-input-1591-233434f52313>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   disorders.max()
# Entity                 Zimbabwe
# Year                       2017
# Schizophrenia           0.37511
# BipolarDisorder        1.206597
# EatingDisorders        0.943991
# AnxietyDisorders        8.96733
# DrugUseDisorders       3.452476
# Depression             6.602754
# AlcoholUseDisorders    5.474668
# dtype: object

# %%
disorders.Depression.nsmallest(3)
# Out:
# 28    2.139903
# 29    2.141201
# 30    2.143395
# Name: Depression, dtype: float64

# %%
disorders.Depression.nlargest(3)
# Out:
# 2245    6.602754
# 2246    6.601250
# 2247    6.598258
# Name: Depression, dtype: float64

# %%
disorders.head()
# Out:
#         Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 0  Afghanistan  AFG  1990       0.160560         0.697779         0.101855
# 1  Afghanistan  AFG  1991       0.160312         0.697961         0.099313
# 2  Afghanistan  AFG  1992       0.160135         0.698107         0.096692
# 3  Afghanistan  AFG  1993       0.160037         0.698257         0.094336
# 4  Afghanistan  AFG  1994       0.160022         0.698469         0.092439
#
#    AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 0          4.828830          1.677082    4.071831             0.672404
# 1          4.829740          1.684746    4.079531             0.671768
# 2          4.831108          1.694334    4.088358             0.670644
# 3          4.830864          1.705320    4.096190             0.669738
# 4          4.829423          1.716069    4.099582             0.669260

# %%
disorders.head(4)
# Out:
#         Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 0  Afghanistan  AFG  1990       0.160560         0.697779         0.101855
# 1  Afghanistan  AFG  1991       0.160312         0.697961         0.099313
# 2  Afghanistan  AFG  1992       0.160135         0.698107         0.096692
# 3  Afghanistan  AFG  1993       0.160037         0.698257         0.094336
#
#    AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 0          4.828830          1.677082    4.071831             0.672404
# 1          4.829740          1.684746    4.079531             0.671768
# 2          4.831108          1.694334    4.088358             0.670644
# 3          4.830864          1.705320    4.096190             0.669738

# %%
disorders.tail()
# Out:
#         Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 6463  Zimbabwe  ZWE  2013       0.155670         0.607993         0.117248
# 6464  Zimbabwe  ZWE  2014       0.155993         0.608610         0.118073
# 6465  Zimbabwe  ZWE  2015       0.156465         0.609363         0.119470
# 6466  Zimbabwe  ZWE  2016       0.157111         0.610234         0.121456
# 6467  Zimbabwe  ZWE  2017       0.157963         0.611242         0.124443
#
#       AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 6463          3.090168          0.766280    3.128192             1.515641
# 6464          3.093964          0.768914    3.140290             1.515470
# 6465          3.098687          0.771802    3.155710             1.514751
# 6466          3.104294          0.772275    3.174134             1.513269
# 6467          3.110926          0.772648    3.192789             1.510943

# %%
disorders.tail(3)
# Out:
#         Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 6465  Zimbabwe  ZWE  2015       0.156465         0.609363         0.119470
# 6466  Zimbabwe  ZWE  2016       0.157111         0.610234         0.121456
# 6467  Zimbabwe  ZWE  2017       0.157963         0.611242         0.124443
#
#       AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 6465          3.098687          0.771802    3.155710             1.514751
# 6466          3.104294          0.772275    3.174134             1.513269
# 6467          3.110926          0.772648    3.192789             1.510943

# %%
disorders[:]
# Out:
#            Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 0     Afghanistan  AFG  1990       0.160560         0.697779         0.101855
# 1     Afghanistan  AFG  1991       0.160312         0.697961         0.099313
# 2     Afghanistan  AFG  1992       0.160135         0.698107         0.096692
# 3     Afghanistan  AFG  1993       0.160037         0.698257         0.094336
# 4     Afghanistan  AFG  1994       0.160022         0.698469         0.092439
# ...           ...  ...   ...            ...              ...              ...
# 6463     Zimbabwe  ZWE  2013       0.155670         0.607993         0.117248
# 6464     Zimbabwe  ZWE  2014       0.155993         0.608610         0.118073
# 6465     Zimbabwe  ZWE  2015       0.156465         0.609363         0.119470
# 6466     Zimbabwe  ZWE  2016       0.157111         0.610234         0.121456
# 6467     Zimbabwe  ZWE  2017       0.157963         0.611242         0.124443
#
#       AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 0             4.828830          1.677082    4.071831             0.672404
# 1             4.829740          1.684746    4.079531             0.671768
# 2             4.831108          1.694334    4.088358             0.670644
# 3             4.830864          1.705320    4.096190             0.669738
# 4             4.829423          1.716069    4.099582             0.669260
# ...                ...               ...         ...                  ...
# 6463          3.090168          0.766280    3.128192             1.515641
# 6464          3.093964          0.768914    3.140290             1.515470
# 6465          3.098687          0.771802    3.155710             1.514751
# 6466          3.104294          0.772275    3.174134             1.513269
# 6467          3.110926          0.772648    3.192789             1.510943
#
# [6468 rows x 10 columns]

# %%
disorders[:7]
# Out:
#         Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 0  Afghanistan  AFG  1990       0.160560         0.697779         0.101855
# 1  Afghanistan  AFG  1991       0.160312         0.697961         0.099313
# 2  Afghanistan  AFG  1992       0.160135         0.698107         0.096692
# 3  Afghanistan  AFG  1993       0.160037         0.698257         0.094336
# 4  Afghanistan  AFG  1994       0.160022         0.698469         0.092439
# 5  Afghanistan  AFG  1995       0.160076         0.698695         0.090980
# 6  Afghanistan  AFG  1996       0.160249         0.698914         0.089709
#
#    AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 0          4.828830          1.677082    4.071831             0.672404
# 1          4.829740          1.684746    4.079531             0.671768
# 2          4.831108          1.694334    4.088358             0.670644
# 3          4.830864          1.705320    4.096190             0.669738
# 4          4.829423          1.716069    4.099582             0.669260
# 5          4.828337          1.728112    4.104207             0.668746
# 6          4.828083          1.737643    4.107500             0.667727

# %%
disorders[-20:]
# Out:
#         Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 6448  Zimbabwe  ZWE  1998       0.163029         0.608195         0.142170
# 6449  Zimbabwe  ZWE  1999       0.162963         0.608294         0.142084
# 6450  Zimbabwe  ZWE  2000       0.162836         0.608295         0.141898
# 6451  Zimbabwe  ZWE  2001       0.162513         0.608099         0.140559
# 6452  Zimbabwe  ZWE  2002       0.161932         0.607692         0.138497
# 6453  Zimbabwe  ZWE  2003       0.161206         0.607226         0.135857
# 6454  Zimbabwe  ZWE  2004       0.160441         0.606830         0.132543
# 6455  Zimbabwe  ZWE  2005       0.159742         0.606630         0.129970
# 6456  Zimbabwe  ZWE  2006       0.158873         0.606588         0.126681
# 6457  Zimbabwe  ZWE  2007       0.157715         0.606590         0.123463
# 6458  Zimbabwe  ZWE  2008       0.156553         0.606656         0.119728
# 6459  Zimbabwe  ZWE  2009       0.155660         0.606758         0.117229
# 6460  Zimbabwe  ZWE  2010       0.155312         0.606897         0.116347
# 6461  Zimbabwe  ZWE  2011       0.155354         0.607124         0.116226
# 6462  Zimbabwe  ZWE  2012       0.155465         0.607495         0.116789
# 6463  Zimbabwe  ZWE  2013       0.155670         0.607993         0.117248
# 6464  Zimbabwe  ZWE  2014       0.155993         0.608610         0.118073
# 6465  Zimbabwe  ZWE  2015       0.156465         0.609363         0.119470
# 6466  Zimbabwe  ZWE  2016       0.157111         0.610234         0.121456
# 6467  Zimbabwe  ZWE  2017       0.157963         0.611242         0.124443
#
#       AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 6448          3.099782          0.752830    3.083283             1.483105
# 6449          3.100378          0.749318    3.074554             1.487476
# 6450          3.100264          0.746757    3.069722             1.488815
# 6451          3.098659          0.741341    3.072727             1.487509
# 6452          3.095492          0.733791    3.080942             1.485264
# 6453          3.091844          0.724705    3.089274             1.482823
# 6454          3.088682          0.718317    3.096351             1.480891
# 6455          3.086927          0.716474    3.102648             1.480095
# 6456          3.085964          0.720239    3.104970             1.483598
# 6457          3.084816          0.729464    3.104822             1.492068
# 6458          3.083928          0.739987    3.103491             1.502307
# 6459          3.083515          0.750769    3.102520             1.511053
# 6460          3.083865          0.756577    3.105459             1.514951
# 6461          3.085099          0.760148    3.109526             1.515236
# 6462          3.087210          0.763839    3.118072             1.515493
# 6463          3.090168          0.766280    3.128192             1.515641
# 6464          3.093964          0.768914    3.140290             1.515470
# 6465          3.098687          0.771802    3.155710             1.514751
# 6466          3.104294          0.772275    3.174134             1.513269
# 6467          3.110926          0.772648    3.192789             1.510943

# %%
disorders[1005:1015]
# Out:
#           Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 1005  Cape Verde  CPV  2015       0.189409         0.709517         0.167825
# 1006  Cape Verde  CPV  2016       0.189658         0.709863         0.168722
# 1007  Cape Verde  CPV  2017       0.189880         0.710184         0.169252
# 1008   Caribbean  NaN  1990       0.193353         0.892215         0.237873
# 1009   Caribbean  NaN  1991       0.193261         0.892355         0.236092
# 1010   Caribbean  NaN  1992       0.193168         0.892420         0.234706
# 1011   Caribbean  NaN  1993       0.193079         0.892409         0.233767
# 1012   Caribbean  NaN  1994       0.193004         0.892320         0.233146
# 1013   Caribbean  NaN  1995       0.192945         0.892139         0.232740
# 1014   Caribbean  NaN  1996       0.192873         0.891850         0.232821
#
#       AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 1005          2.995634          0.624374    4.092633             1.006284
# 1006          2.997182          0.627406    4.087075             1.007183
# 1007          2.998977          0.630609    4.082451             1.007670
# 1008          4.552197          0.731988    3.338749             1.638000
# 1009          4.556013          0.737540    3.344202             1.643247
# 1010          4.559185          0.743024    3.344391             1.647712
# 1011          4.561675          0.747247    3.342882             1.651439
# 1012          4.563304          0.750577    3.338455             1.654505
# 1013          4.563882          0.752325    3.331546             1.656928
# 1014          4.562894          0.752630    3.319607             1.658346

# %%
disorders['Depression']
# Out:
# 0       4.071831
# 1       4.079531
# 2       4.088358
# 3       4.096190
# 4       4.099582
#           ...
# 6463    3.128192
# 6464    3.140290
# 6465    3.155710
# 6466    3.174134
# 6467    3.192789
# Name: Depression, Length: 6468, dtype: float64

# %%
disorders[['Depression', 'EatingDisorders']]
# Out:
#       Depression  EatingDisorders
# 0       4.071831         0.101855
# 1       4.079531         0.099313
# 2       4.088358         0.096692
# 3       4.096190         0.094336
# 4       4.099582         0.092439
# ...          ...              ...
# 6463    3.128192         0.117248
# 6464    3.140290         0.118073
# 6465    3.155710         0.119470
# 6466    3.174134         0.121456
# 6467    3.192789         0.124443
#
# [6468 rows x 2 columns]

# %%
disorders[disorders.Depression>4.5]
# Out:
#              Entity Code  Year  Schizophrenia  BipolarDisorder  \
# 280     Australasia  NaN  1990       0.357272         1.139509
# 281     Australasia  NaN  1991       0.357778         1.142420
# 282     Australasia  NaN  1992       0.358273         1.145166
# 283     Australasia  NaN  1993       0.358720         1.147570
# 284     Australasia  NaN  1994       0.359051         1.149378
# ...             ...  ...   ...            ...              ...
# 6099  United States  USA  2013       0.336404         0.652479
# 6100  United States  USA  2014       0.335860         0.652195
# 6101  United States  USA  2015       0.335243         0.651890
# 6102  United States  USA  2016       0.334578         0.651569
# 6103  United States  USA  2017       0.333890         0.651236
#
#       EatingDisorders  AnxietyDisorders  DrugUseDisorders  Depression  \
# 280          0.688709          6.814156          2.128077    4.543521
# 281          0.691371          6.814689          2.178211    4.587576
# 282          0.693961          6.816471          2.224164    4.625287
# 283          0.698179          6.818327          2.261818    4.658598
# 284          0.702619          6.818651          2.290779    4.683520
# ...               ...               ...               ...         ...
# 6099         0.528946          6.671047          3.110712    4.772422
# 6100         0.525990          6.660473          3.181115    4.782222
# 6101         0.522109          6.650662          3.262674    4.795954
# 6102         0.517728          6.642099          3.353142    4.813114
# 6103         0.512844          6.635055          3.452476    4.835610
#
#       AlcoholUseDisorders
# 280              1.404956
# 281              1.440458
# 282              1.472932
# 283              1.501013
# 284              1.523157
# ...                   ...
# 6099             2.005814
# 6100             2.011345
# 6101             2.018738
# 6102             2.028263
# 6103             2.040087
#
# [377 rows x 10 columns]

# %%
disorders[disorders.Depression.between(2, 2.5)]
# Out:
#         Entity Code  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 28     Albania  ALB  1990       0.193413         0.695013         0.130782
# 29     Albania  ALB  1991       0.193393         0.695294         0.129102
# 30     Albania  ALB  1992       0.193405         0.695603         0.127063
# 31     Albania  ALB  1993       0.193438         0.695922         0.126019
# 32     Albania  ALB  1994       0.193491         0.696255         0.125402
# ...        ...  ...   ...            ...              ...              ...
# 5063  Slovakia  SVK  2013       0.207415         0.711271         0.227514
# 5064  Slovakia  SVK  2014       0.207701         0.711564         0.229772
# 5065  Slovakia  SVK  2015       0.207971         0.711868         0.232232
# 5066  Slovakia  SVK  2016       0.208214         0.712163         0.233693
# 5067  Slovakia  SVK  2017       0.208419         0.712434         0.235475
#
#       AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 28            3.327587          0.497616    2.139903             1.709465
# 29            3.330348          0.495687    2.141201             1.708135
# 30            3.333438          0.495337    2.143395             1.706053
# 31            3.336688          0.494085    2.145263             1.703585
# 32            3.340089          0.492630    2.150070             1.701142
# ...                ...               ...         ...                  ...
# 5063          3.450103          0.693418    2.412660             2.445520
# 5064          3.449012          0.689890    2.408812             2.458422
# 5065          3.447717          0.686567    2.406614             2.472140
# 5066          3.446144          0.682712    2.403851             2.486322
# 5067          3.444251          0.678350    2.401999             2.500482
#
# [240 rows x 10 columns]

# %%
disorders.loc[1000:1030, 'EatingDisorders':'Depression']
# Out:
#       EatingDisorders  AnxietyDisorders  DrugUseDisorders  Depression
# 1000         0.160758          2.990787          0.609278    4.118430
# 1001         0.162008          2.991367          0.611220    4.113623
# 1002         0.163585          2.992142          0.614276    4.108492
# 1003         0.165331          2.993117          0.617621    4.103363
# 1004         0.166650          2.994288          0.620602    4.097893
# 1005         0.167825          2.995634          0.624374    4.092633
# 1006         0.168722          2.997182          0.627406    4.087075
# 1007         0.169252          2.998977          0.630609    4.082451
# 1008         0.237873          4.552197          0.731988    3.338749
# 1009         0.236092          4.556013          0.737540    3.344202
# 1010         0.234706          4.559185          0.743024    3.344391
# 1011         0.233767          4.561675          0.747247    3.342882
# 1012         0.233146          4.563304          0.750577    3.338455
# 1013         0.232740          4.563882          0.752325    3.331546
# 1014         0.232821          4.562894          0.752630    3.319607
# 1015         0.233489          4.560618          0.751169    3.301736
# 1016         0.234253          4.557776          0.749196    3.279424
# 1017         0.235272          4.555091          0.747427    3.257268
# 1018         0.236044          4.553336          0.746064    3.236526
# 1019         0.236901          4.552435          0.745625    3.217038
# 1020         0.238082          4.551744          0.745733    3.198076
# 1021         0.239667          4.551151          0.745270    3.179615
# 1022         0.241113          4.550712          0.744970    3.163253
# 1023         0.242507          4.550332          0.743675    3.149348
# 1024         0.244009          4.550174          0.741453    3.136518
# 1025         0.245824          4.550556          0.738570    3.123540
# 1026         0.247903          4.551393          0.736077    3.112308
# 1027         0.249579          4.552460          0.733549    3.103374
# 1028         0.251394          4.554530          0.731544    3.098382
# 1029         0.252788          4.556424          0.729276    3.095358
# 1030         0.254113          4.557291          0.728389    3.090492

# %%
disorders = disorders.drop(columns=['Code'])
disorders
# Out:
#            Entity  Year  Schizophrenia  BipolarDisorder  EatingDisorders  \
# 0     Afghanistan  1990       0.160560         0.697779         0.101855
# 1     Afghanistan  1991       0.160312         0.697961         0.099313
# 2     Afghanistan  1992       0.160135         0.698107         0.096692
# 3     Afghanistan  1993       0.160037         0.698257         0.094336
# 4     Afghanistan  1994       0.160022         0.698469         0.092439
# ...           ...   ...            ...              ...              ...
# 6463     Zimbabwe  2013       0.155670         0.607993         0.117248
# 6464     Zimbabwe  2014       0.155993         0.608610         0.118073
# 6465     Zimbabwe  2015       0.156465         0.609363         0.119470
# 6466     Zimbabwe  2016       0.157111         0.610234         0.121456
# 6467     Zimbabwe  2017       0.157963         0.611242         0.124443
#
#       AnxietyDisorders  DrugUseDisorders  Depression  AlcoholUseDisorders
# 0             4.828830          1.677082    4.071831             0.672404
# 1             4.829740          1.684746    4.079531             0.671768
# 2             4.831108          1.694334    4.088358             0.670644
# 3             4.830864          1.705320    4.096190             0.669738
# 4             4.829423          1.716069    4.099582             0.669260
# ...                ...               ...         ...                  ...
# 6463          3.090168          0.766280    3.128192             1.515641
# 6464          3.093964          0.768914    3.140290             1.515470
# 6465          3.098687          0.771802    3.155710             1.514751
# 6466          3.104294          0.772275    3.174134             1.513269
# 6467          3.110926          0.772648    3.192789             1.510943
#
# [6468 rows x 9 columns]

# %%
disorders.isna().sum()
# Out:
# Entity                 0
# Year                   0
# Schizophrenia          0
# BipolarDisorder        0
# EatingDisorders        0
# AnxietyDisorders       0
# DrugUseDisorders       0
# Depression             0
# AlcoholUseDisorders    0
# dtype: int64

# %%
disorders.isna().all()
# Out:
# Entity                 False
# Year                   False
# Schizophrenia          False
# BipolarDisorder        False
# EatingDisorders        False
# AnxietyDisorders       False
# DrugUseDisorders       False
# Depression             False
# AlcoholUseDisorders    False
# dtype: bool

# %%
disorders.count().plot.bar()
# Out:
# <Axes: >

# %%
disorders.count().plot.barh()
# Out:
# <Axes: >

# %%
disorders.Depression.plot.kde().set(title="Distribution of Depression Datapoints", xlabel="")
# Out:
# [Text(0.5, 1.0, 'Distribution of Depression Datapoints'), Text(0.5, 0, '')]

# %%
disorders.corr()
# Out:
# <ipython-input-1613-503556048be3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   disorders.corr()
#                          Year  Schizophrenia  BipolarDisorder  \
# Year                 1.000000       0.039163         0.012273
# Schizophrenia        0.039163       1.000000         0.198456
# BipolarDisorder      0.012273       0.198456         1.000000
# EatingDisorders      0.086793       0.668816         0.708055
# AnxietyDisorders     0.012517       0.469325         0.663745
# DrugUseDisorders     0.058543       0.475203         0.363871
# Depression          -0.035427       0.167478         0.148557
# AlcoholUseDisorders  0.017217      -0.059207         0.079694
#
#                      EatingDisorders  AnxietyDisorders  DrugUseDisorders  \
# Year                        0.086793          0.012517          0.058543
# Schizophrenia               0.668816          0.469325          0.475203
# BipolarDisorder             0.708055          0.663745          0.363871
# EatingDisorders             1.000000          0.698026          0.494187
# AnxietyDisorders            0.698026          1.000000          0.616077
# DrugUseDisorders            0.494187          0.616077          1.000000
# Depression                  0.240716          0.379012          0.366539
# AlcoholUseDisorders         0.035254         -0.136502         -0.113245
#
#                      Depression  AlcoholUseDisorders
# Year                  -0.035427             0.017217
# Schizophrenia          0.167478            -0.059207
# BipolarDisorder        0.148557             0.079694
# EatingDisorders        0.240716             0.035254
# AnxietyDisorders       0.379012            -0.136502
# DrugUseDisorders       0.366539            -0.113245
# Depression             1.000000             0.050146
# AlcoholUseDisorders    0.050146             1.000000

# %%
sns.heatmap(disorders.corr())
# Out:
# <ipython-input-1614-24ceeacdac84>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(disorders.corr())
# <Axes: >

# %%
sns.heatmap(disorders.corr(), annot=True)
# Out:
# <ipython-input-1615-11b7066a476b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(disorders.corr(), annot=True)
# <Axes: >

# %%
sns.heatmap(disorders.corr(), annot=True, cmap='Blues')
# Out:
# <ipython-input-1616-2786b1488f05>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(disorders.corr(), annot=True, cmap='Blues')
# <Axes: >

# %%
plt.scatter(disorders.Schizophrenia,disorders.Depression)
plt.title("Distribution of datapoints (Depression vs Schizophrenia)")
plt.show()

# %%
plt.scatter(disorders.BipolarDisorder,disorders.Depression)
plt.title("Distribution of datapoints (Depression vs Bipolar Disorder)")
plt.show()

# %%
plt.scatter(disorders.EatingDisorders,disorders.Depression)
plt.title("Distribution of datapoints (Depression vs Eating Disorders)")
plt.show()

# %%
plt.scatter(disorders.AnxietyDisorders,disorders.Depression)
plt.title("Distribution of datapoints (Depression vs Anxiety Disorders)")
plt.show()

# %%
plt.scatter(disorders.DrugUseDisorders,disorders.Depression)
plt.title("Distribution of datapoints (Depression vs Drug Use Disorders)")
plt.show()

# %%
plt.scatter(disorders.AlcoholUseDisorders,disorders.Depression)
plt.title("Distribution of datapoints (Depression vs Alocohol Use Disorders)")
plt.show()

# %%
sns.jointplot(x='BipolarDisorder', y='Depression', data=disorders, kind='reg')

# %%
sns.jointplot(x='EatingDisorders', y='Depression', data=disorders, kind='reg')

# %%
sns.boxplot(x=disorders['Depression'])
# Out:
# <Axes: xlabel='Depression'>

# %%
sns.violinplot(x=disorders['AnxietyDisorders'])
# Out:
# <Axes: xlabel='AnxietyDisorders'>

# %%
sns.regplot(x='AnxietyDisorders', y='Depression', data=disorders,ci=None)
# Out:
# <Axes: xlabel='AnxietyDisorders', ylabel='Depression'>

# %%
sns.lmplot(x='DrugUseDisorders', y='Depression', data=disorders)

# %%
disordersWorld = disorders.drop(["Entity"], axis=1)
disordersWorld.isna().sum()
# Out:
# Year                   0
# Schizophrenia          0
# BipolarDisorder        0
# EatingDisorders        0
# AnxietyDisorders       0
# DrugUseDisorders       0
# Depression             0
# AlcoholUseDisorders    0
# dtype: int64

# %%
disordersWorld = pd.DataFrame(disordersWorld).groupby(["Year"]).mean()

# %%
disordersWorld
# Out:
#       Schizophrenia  BipolarDisorder  EatingDisorders  AnxietyDisorders  \
# Year
# 1990       0.209548         0.715392         0.221774          3.957269
# 1991       0.209586         0.715740         0.222076          3.960009
# 1992       0.209634         0.716091         0.222481          3.962778
# 1993       0.209690         0.716430         0.223033          3.965405
# 1994       0.209751         0.716755         0.223710          3.967976
# 1995       0.209810         0.717037         0.224514          3.970051
# 1996       0.209877         0.717293         0.225581          3.972869
# 1997       0.209966         0.717564         0.226980          3.977437
# 1998       0.210075         0.717843         0.228581          3.982739
# 1999       0.210200         0.718117         0.230264          3.987662
# 2000       0.210335         0.718371         0.231838          3.990991
# 2001       0.210530         0.718577         0.233510          3.993043
# 2002       0.210808         0.718758         0.235497          3.995073
# 2003       0.211125         0.718939         0.237636          3.997061
# 2004       0.211430         0.719138         0.239750          3.998890
# 2005       0.211671         0.719366         0.241657          4.000271
# 2006       0.211931         0.719641         0.243622          4.001204
# 2007       0.212291         0.719965         0.245934          4.001978
# 2008       0.212685         0.720314         0.248387          4.002786
# 2009       0.213046         0.720644         0.250637          4.003497
# 2010       0.213306         0.720907         0.252502          4.004008
# 2011       0.213497         0.721123         0.254015          4.004142
# 2012       0.213696         0.721351         0.255580          4.004037
# 2013       0.213900         0.721604         0.257151          4.004003
# 2014       0.214105         0.721866         0.258705          4.003861
# 2015       0.214310         0.722138         0.260198          4.003509
# 2016       0.214511         0.722409         0.261535          4.002900
# 2017       0.214705         0.722693         0.262806          4.002347
#
#       DrugUseDisorders  Depression  AlcoholUseDisorders
# Year
# 1990          0.808283    3.506288             1.546533
# 1991          0.813466    3.510948             1.553500
# 1992          0.818692    3.515033             1.559927
# 1993          0.823780    3.518531             1.565611
# 1994          0.828389    3.521437             1.570127
# 1995          0.832391    3.523328             1.573532
# 1996          0.837124    3.524659             1.576549
# 1997          0.843217    3.525602             1.579598
# 1998          0.849664    3.525968             1.582334
# 1999          0.855211    3.525664             1.584450
# 2000          0.858849    3.524262             1.585654
# 2001          0.861183    3.522087             1.585276
# 2002          0.863240    3.519421             1.583544
# 2003          0.865176    3.516446             1.581495
# 2004          0.866875    3.513080             1.580094
# 2005          0.868389    3.509253             1.580366
# 2006          0.870548    3.502707             1.584365
# 2007          0.873739    3.492855             1.591869
# 2008          0.877329    3.482217             1.600392
# 2009          0.880920    3.472895             1.607415
# 2010          0.883748    3.467328             1.610462
# 2011          0.886216    3.464513             1.610315
# 2012          0.889015    3.461950             1.609455
# 2013          0.891820    3.459763             1.607668
# 2014          0.894665    3.458056             1.604898
# 2015          0.897623    3.456916             1.601098
# 2016          0.900660    3.456299             1.596272
# 2017          0.903575    3.456795             1.590201

# %%
disordersWorld.shape
# Out:
# (28, 7)

# %%
disordersWorld.ndim
# Out:
# 2

# %%
disordersWorld.describe()
# Out:
#        Schizophrenia  BipolarDisorder  EatingDisorders  AnxietyDisorders  \
# count      28.000000        28.000000        28.000000         28.000000
# mean        0.211644         0.719145         0.239998          3.989921
# std         0.001802         0.002147         0.014085          0.016190
# min         0.209548         0.715392         0.221774          3.957269
# 25%         0.209944         0.717497         0.226630          3.976295
# 50%         0.211278         0.719039         0.238693          3.997975
# 75%         0.213354         0.720961         0.252880          4.003050
# max         0.214705         0.722693         0.262806          4.004142
#
#        DrugUseDisorders  Depression  AlcoholUseDisorders
# count         28.000000   28.000000            28.000000
# mean           0.862278    3.497654             1.585821
# std            0.027809    0.027251             0.017187
# min            0.808283    3.456299             1.546533
# 25%            0.841694    3.466624             1.578836
# 50%            0.866025    3.510100             1.584407
# 75%            0.884365    3.521599             1.600569
# max            0.903575    3.525968             1.610462

# %%
disordersWorld.index
# Out:
# Int64Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name='Year')

# %%
disordersWorld.columns
# Out:
# Index(['Schizophrenia', 'BipolarDisorder', 'EatingDisorders',
#        'AnxietyDisorders', 'DrugUseDisorders', 'Depression',
#        'AlcoholUseDisorders'],
#       dtype='object')

# %%
disordersWorld.nunique()
# Out:
# Schizophrenia          28
# BipolarDisorder        28
# EatingDisorders        28
# AnxietyDisorders       28
# DrugUseDisorders       28
# Depression             28
# AlcoholUseDisorders    28
# dtype: int64

# %%
disordersWorld.duplicated()
# Out:
# Year
# 1990    False
# 1991    False
# 1992    False
# 1993    False
# 1994    False
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# 2000    False
# 2001    False
# 2002    False
# 2003    False
# 2004    False
# 2005    False
# 2006    False
# 2007    False
# 2008    False
# 2009    False
# 2010    False
# 2011    False
# 2012    False
# 2013    False
# 2014    False
# 2015    False
# 2016    False
# 2017    False
# dtype: bool

# %%
disordersWorld.corr()
# Out:
#                      Schizophrenia  BipolarDisorder  EatingDisorders  \
# Schizophrenia             1.000000         0.974496         0.995638
# BipolarDisorder           0.974496         1.000000         0.987941
# EatingDisorders           0.995638         0.987941         1.000000
# AnxietyDisorders          0.839428         0.918520         0.884512
# DrugUseDisorders          0.937075         0.990159         0.963065
# Depression               -0.949082        -0.860770        -0.919582
# AlcoholUseDisorders       0.833532         0.890821         0.855320
#
#                      AnxietyDisorders  DrugUseDisorders  Depression  \
# Schizophrenia                0.839428          0.937075   -0.949082
# BipolarDisorder              0.918520          0.990159   -0.860770
# EatingDisorders              0.884512          0.963065   -0.919582
# AnxietyDisorders             1.000000          0.957700   -0.653412
# DrugUseDisorders             0.957700          1.000000   -0.788824
# Depression                  -0.653412         -0.788824    1.000000
# AlcoholUseDisorders          0.889860          0.902659   -0.728036
#
#                      AlcoholUseDisorders
# Schizophrenia                   0.833532
# BipolarDisorder                 0.890821
# EatingDisorders                 0.855320
# AnxietyDisorders                0.889860
# DrugUseDisorders                0.902659
# Depression                     -0.728036
# AlcoholUseDisorders             1.000000

# %%
sns.heatmap(disordersWorld.corr(), annot=True).set(title="Correlation Between Different Disorders")
# Out:
# [Text(0.5, 1.0, 'Correlation Between Different Disorders')]

# %%
sns.barplot(data=disordersWorld, orient='h').set(xlabel='Percentage of Population', title="Mental Health Disorders (World View)")
# Out:
# [Text(0.5, 0, 'Percentage of Population'),
#  Text(0.5, 1.0, 'Mental Health Disorders (World View)')]

# %%
disordersWorld.plot.line().set(ylabel="Percentage of Population")
# Out:
# [Text(0, 0.5, 'Percentage of Population')]

# %%
disordersWorld.Schizophrenia.plot.line().set(ylabel="Schizophrenia (% of population having it)")
# Out:
# [Text(0, 0.5, 'Schizophrenia (% of population having it)')]

# %%
disordersWorld.BipolarDisorder.plot.line().set(ylabel="Bipolar Disorders (% of population having it)")
# Out:
# [Text(0, 0.5, 'Bipolar Disorders (% of population having it)')]

# %%
disordersWorld.EatingDisorders.plot.line().set(ylabel="Eating Disorders (% of population having it)")
# Out:
# [Text(0, 0.5, 'Eating Disorders (% of population having it)')]

# %%
disordersWorld.AnxietyDisorders.plot.line().set(ylabel="Anxiety Disorders (% of population having it)")
# Out:
# [Text(0, 0.5, 'Anxiety Disorders (% of population having it)')]

# %%
disordersWorld.DrugUseDisorders.plot.line().set(ylabel="Drug Use Disorders (% of population having it)")
# Out:
# [Text(0, 0.5, 'Drug Use Disorders (% of population having it)')]

# %%
disordersWorld.Depression.plot.line().set(ylabel="Depression (% of population having it)")
# Out:
# [Text(0, 0.5, 'Depression (% of population having it)')]

# %%
disordersWorld.AlcoholUseDisorders.plot.line().set(ylabel="Alcohol Use Disorders (% of population having it)")
# Out:
# [Text(0, 0.5, 'Alcohol Use Disorders (% of population having it)')]

# %%
x = disorders[['Schizophrenia', 'BipolarDisorder', 'EatingDisorders', 'AnxietyDisorders', 'DrugUseDisorders', 'AlcoholUseDisorders']]
x
# Out:
#       Schizophrenia  BipolarDisorder  EatingDisorders  AnxietyDisorders  \
# 0          0.160560         0.697779         0.101855          4.828830
# 1          0.160312         0.697961         0.099313          4.829740
# 2          0.160135         0.698107         0.096692          4.831108
# 3          0.160037         0.698257         0.094336          4.830864
# 4          0.160022         0.698469         0.092439          4.829423
# ...             ...              ...              ...               ...
# 6463       0.155670         0.607993         0.117248          3.090168
# 6464       0.155993         0.608610         0.118073          3.093964
# 6465       0.156465         0.609363         0.119470          3.098687
# 6466       0.157111         0.610234         0.121456          3.104294
# 6467       0.157963         0.611242         0.124443          3.110926
#
#       DrugUseDisorders  AlcoholUseDisorders
# 0             1.677082             0.672404
# 1             1.684746             0.671768
# 2             1.694334             0.670644
# 3             1.705320             0.669738
# 4             1.716069             0.669260
# ...                ...                  ...
# 6463          0.766280             1.515641
# 6464          0.768914             1.515470
# 6465          0.771802             1.514751
# 6466          0.772275             1.513269
# 6467          0.772648             1.510943
#
# [6468 rows x 6 columns]

# %%
y = disorders['Depression']
y
# Out:
# 0       4.071831
# 1       4.079531
# 2       4.088358
# 3       4.096190
# 4       4.099582
#           ...
# 6463    3.128192
# 6464    3.140290
# 6465    3.155710
# 6466    3.174134
# 6467    3.192789
# Name: Depression, Length: 6468, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
x_train.shape
# Out:
# (4851, 6)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression(fit_intercept = True)
regressor = regressor.fit(x_train, y_train)

# %%
print('Linear Model Coefficient (m): ', regressor.coef_)
print('Linear Model Intercept (b): ', regressor.intercept_)
# Out:
# Linear Model Coefficient (m):  [-2.78611872 -1.23113194  0.70760191  0.25303977  0.32120983  0.11842917]
# Linear Model Intercept (b):  3.332056000234563

# %%
y_predict = regressor.predict(x_test)
y_predict
# Out:
# array([3.23089458, 3.4301233 , 3.41117655, ..., 3.39117297, 3.69611957,
#        3.54102037])

# %%
y_test
# Out:
# 2022    5.489475
# 1902    4.164680
# 1666    3.074819
# 2066    4.340423
# 5212    2.821500
#           ...
# 2999    3.271182
# 4040    2.859093
# 5047    2.538367
# 764     3.902352
# 1635    2.588871
# Name: Depression, Length: 1617, dtype: float64

# %%
from sklearn import metrics
acc = metrics.mean_squared_error(y_test, y_predict)
print("Mean Square Error: ", acc)
acc = metrics.mean_absolute_error(y_test, y_predict)
print("Mean Absolute Error: ", acc)
wts = regressor.coef_
incpt = regressor.intercept_
print("Slope: ", wts, "\nIntercept ", incpt)
# Out:
# Mean Square Error:  0.3485639688411424
# Mean Absolute Error:  0.46563167394972427
# Slope:  [-2.78611872 -1.23113194  0.70760191  0.25303977  0.32120983  0.11842917]
# Intercept  3.332056000234563

# %%
regressor1 = pd.DataFrame({'Actual value':y_test, 'predicted value':y_predict})
regressor1.head()
# Out:
#       Actual value  predicted value
# 2022      5.489475         3.230895
# 1902      4.164680         3.430123
# 1666      3.074819         3.411177
# 2066      4.340423         4.081722
# 5212      2.821500         3.625155

# %%
# Predictions
inpredict = [
    [0.1, 0.5, 0.1,  5, 1.5, 0.5],
    [0.12, 0.43, 0.12, 4.5, 1.34, 0.45],
    [0.11, 0.41, 0.13, 4.99, 1.49, 5.1]
]
regressor.predict(inpredict)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.31486651, 4.17564049, 4.95806693])
